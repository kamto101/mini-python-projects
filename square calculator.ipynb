# %% [markdown]
# <a href="https://www.kaggle.com/code/kamtoeze/notebook3442e5d9ae?scriptVersionId=104778329" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# **SQUARE CALCULATOR!!!**
#
# Welcome to square calculator! how does it work? Thats easy, just put any number and it will be squared for you. come on, try it for yourself!

# %%
number = " "
action = " "
while action != "g":
    number = int(input("insert any number "))
    print(number, "squared is ", number * number)
    action = input("type 'g' to close application or 'c' to continue " )
